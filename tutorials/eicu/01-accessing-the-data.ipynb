# %% [markdown]
# # eICU Collaborative Research Database
#
# # Notebook 1: Accessing the data
#
# The aim of this notebook is to get set up with access to a demo version of the [eICU Collaborative Research Database](http://eicu-crd.mit.edu/). The demo is a subset of the full database, limited to 100 patients.

# %% [markdown]
# ## Prerequisites
#
# - If you do not have a Gmail account, please create one at http://www.gmail.com.
# - If you have not yet signed the data use agreement (DUA) sent by the organizers, please do so now to get access to the dataset.

# %% [markdown]
# ## Setup
#
# To run the queries in this notebook, you will need to create a copy by clicking *File" > "Save a copy in Drive..."* from the menu. Before running a cell in the notebook, check for the green "CONNECTED" check mark in top right corner.
#
# Next we'll start playing with the data. First, you need to run some initialization code. You can run the following cell by clicking on the triangle button when you hover over the [ ] space on the top-left corner of the code cell below.

# %%
# Import libraries
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path

# Make pandas dataframes prettier
from IPython.display import display, HTML

# Access data using Google BigQuery.
from google.colab import auth
from google.cloud import bigquery

# %% [markdown]
# Before running any queries, you need to first authenticate yourself by running the following cell. If you are running it for the first time, it will ask you to follow a link to log in using your Gmail account, and accept the data access requests to your profile. Once this is done, it will generate a string of verification code, which you should paste back to the cell below and press enter.

# %%
auth.authenticate_user()

# %% [markdown]
# ## Querying the dataset
#
# Now we are ready to load the data from the cloud server. The data-hosting project `physionet-data` allows you read-only access to the eICU Collaborative Research Database demo (as well as the complete eICU database, the MIMIC-III database and the MIMIC-CXR database). Let's see which datasets are available in this project.

# %%
project_id='aarhus-critical-2019-team'
os.environ["GOOGLE_CLOUD_PROJECT"]=project_id

# %%
# create a connection to the database
client = bigquery.Client(project='physionet-data')

# load the dataset list
datasets = client.list_datasets()

# iterate the datasets list
for dataset in datasets:
    did = dataset.dataset_id
    # print the dataset name
    print('Dataset "{}" has the following tables: '.format(did))
    # iterate the tables on the dataset
    for table in client.list_tables(client.dataset(did)):
        # print the table name
        print('- {}'.format(table.table_id))
# Out:
# Dataset "eicu_crd" has the following tables:
# - admissiondrug
# - admissiondx
# - allergy
# - apacheapsvar
# - apachepatientresult
# - apachepredvar
# - careplancareprovider
# - careplaneol
# - careplangeneral
# - careplangoal
# - careplaninfectiousdisease
# - customlab
# - diagnosis
# - hospital
# - infusiondrug
# - intakeoutput
# - lab
# - medication
# - microlab
# - note
# - nurseassessment
# - nursecare
# - nursecharting
# - pasthistory
# - patient
# - physicalexam
# - respiratorycare
# - respiratorycharting
# - treatment
# - vitalaperiodic
# - vitalperiodic
# Dataset "eicu_crd_demo" has the following tables:
# - admissiondrug
# - admissiondx
# - allergy
# - apacheapsvar
# - apachepatientresult
# - apachepredvar
# - careplancareprovider
# - careplaneol
# - careplangeneral
# - careplangoal
# - careplaninfectiousdisease
# - customlab
# - diagnosis
# - hospital
# - infusiondrug
# - intakeoutput
# - lab
# - medication
# - microlab
# - note
# - nurseassessment
# - nursecare
# - nursecharting
# - pasthistory
# - patient
# - physicalexam
# - respiratorycare
# - respiratorycharting
# - treatment
# - vitalaperiodic
# - vitalperiodic
# Dataset "eicu_crd_derived" has the following tables:
# - apache_groups
# - basic_demographics
# - debug_vent_modes
# - debug_vent_tags
# - icustay_detail
# - labsfirstday
# - pivoted_bg
# - pivoted_creatinine
# - pivoted_infusion
# - pivoted_lab
# - pivoted_med
# - pivoted_o2
# - pivoted_score
# - pivoted_treatment_vasopressor
# - pivoted_uo
# - pivoted_vital
# - pivoted_vital_other
# - ventilation_events
# Dataset "mimic_cxr" has the following tables:
# - images
# Dataset "mimic_cxr_derived" has the following tables:
# - densenet_frontal_u0_0__w0_0_predictions
# - densenet_frontal_u0_0__w1_0_predictions
# - densenet_frontal_u0_5__w0_25_predictions
# - densenet_frontal_u1_0__w1_0_predictions
# - densenet_lateral_u0_0__w0_0_predictions
# - densenet_lateral_u0_0__w1_0_predictions
# - densenet_lateral_u0_5__w0_25_predictions
# - densenet_lateral_u1_0__w1_0_predictions
# - labels_train
# - labels_valid
# Dataset "mimiciii_clinical" has the following tables:
# - admissions
# - callout
# - caregivers
# - chartevents
# - cptevents
# - d_cpt
# - d_icd_diagnoses
# - d_icd_procedures
# - d_items
# - d_labitems
# - datetimeevents
# - diagnoses_icd
# - drgcodes
# - icustays
# - inputevents_cv
# - inputevents_mv
# - labevents
# - microbiologyevents
# - outputevents
# - patients
# - prescriptions
# - procedureevents_mv
# - procedures_icd
# - services
# - transfers
# Dataset "mimiciii_demo" has the following tables:
# - admissions
# - callout
# - caregivers
# - chartevents
# - cptevents
# - d_cpt
# - d_icd_diagnoses
# - d_icd_procedures
# - d_items
# - d_labitems
# - datetimeevents
# - diagnoses_icd
# - drgcodes
# - icustays
# - inputevents_cv
# - inputevents_mv
# - labevents
# - microbiologyevents
# - outputevents
# - patients
# - prescriptions
# - procedureevents_mv
# - procedures_icd
# - services
# - transfers
# Dataset "mimiciii_derived" has the following tables:
# - abx_micro_poe
# - abx_poe_list
# - abx_prescriptions_list
# - adenosinedurations
# - angus_sepsis
# - apsiii
# - blood_culture_icu_admit
# - bloodgasfirstday
# - bloodgasfirstdayarterial
# - code_status
# - crrtdurations
# - dobutamine_dose
# - dobutaminedurations
# - dopamine_dose
# - dopaminedurations
# - echodata_structured
# - elixhauser_quan
# - elixhauser_quan_score
# - epinephrine_dose
# - epinephrinedurations
# - explicit_sepsis
# - fluid_map
# - gcsfirstday
# - heightfirstday
# - heightweight
# - icustay_detail
# - icustay_hours
# - icustay_times
# - isupreldurations
# - kdigo_creat
# - kdigo_stages_48hr
# - kdigo_stages_7day
# - kdigo_uo
# - labsfirstday
# - lods
# - martin_sepsis
# - meld
# - meld_copy
# - milrinonedurations
# - mlods
# - norepinephrine_dose
# - norepinephrinedurations
# - noteevents_metadata
# - oasis
# - phenylephrine_dose
# - phenylephrinedurations
# - pivoted_bg
# - pivoted_bg_art
# - pivoted_gcs
# - pivoted_lab
# - pivoted_sofa
# - pivoted_vital
# - qsofa
# - rrt
# - rrtfirstday
# - saps
# - sapsii
# - sepsis_cdc_surveillance
# - sepsis_nqf_0500
# - sirs
# - sofa
# - suspicion_of_infection
# - suspinfect_poe
# - uofirstday
# - urineoutput
# - vasopressin_dose
# - vasopressindurations
# - vasopressordurations
# - ventdurations
# - ventfirstday
# - ventsettings
# - vitalsfirstday
# - weightdurations
# - weightfirstday
# Dataset "mimiciii_notes" has the following tables:
# - echodata
# - noteevents
